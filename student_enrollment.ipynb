# %% [markdown]
# <a href="https://colab.research.google.com/github/GreenBird88/DataScience-Project/blob/main/student_enrollment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


student = pd.read_csv('/content/student enrollment.csv')
student.head(20)
# Out:
#     student_ID  Course  Enrollment_chance
# 0           20       2                  1
# 1           19      11                  1
# 2           19       5                  1
# 3           20      15                  1
# 4           45       3                  0
# 5           50      17                  0
# 6           18      12                  1
# 7           22      11                  1
# 8           21      10                  0
# 9           18      10                  1
# 10          18      14                  1
# 11          18      12                  1
# 12          19      16                  1
# 13          21      11                  1
# 14          18       6                  1
# 15          20      15                  1
# 16          18      10                  1
# 17          18      12                  1
# 18          20       8                  1
# 19          18      16                  1

# %%
variables = student.loc[:,['student_ID','Enrollment_chance']]
# 1 means ACCEPTANCE while 0 means REJECTION
student.plot(x='Enrollment_chance',y='student_ID',style='*')
plt.xlabel('Enrollment_chance')
plt.ylabel('student_ID')
plt.show()

# %%
summary = student.describe()
print(student.info())
print(summary)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   student_ID         4424 non-null   int64
#  1   Course             4424 non-null   int64
#  2   Enrollment_chance  4424 non-null   int64
# dtypes: int64(3)
# memory usage: 103.8 KB
# None
#         student_ID       Course  Enrollment_chance
# count  4424.000000  4424.000000        4424.000000
# mean     23.265145     9.899186           0.548373
# std       7.587816     4.331792           0.497711
# min      17.000000     1.000000           0.000000
# 25%      19.000000     6.000000           0.000000
# 50%      20.000000    10.000000           1.000000
# 75%      25.000000    13.000000           1.000000
# max      70.000000    17.000000           1.000000

# %% [markdown]
# <a href="https://colab.research.google.com/github/GreenBird88/DataScience-Project/blob/main/predictive_maintenance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('/content/machinery.csv')
data.head(20)

# %%
duplicates_machine = data[data['Machine_ID'].duplicated()]
duplicates_fail = data[data['Fail_possibility'].duplicated()]
print(duplicates_machine)
print(duplicates_fail)

# %%
print(data.head())
# Out:
#   Machine_ID  Fail_possibility Failure Type  failure_probability
# 0     M14860              42.8   No Failure                 8.46
# 1     L47181              46.3   No Failure                 0.77
# 2     L47182              49.4   No Failure                 3.31
# 3     L47183              39.5   No Failure                 2.96
# 4     L47184              40.0   No Failure                 1.00

# %%
variables = data.loc[:,['failure_probability','Fail_possibility']]
# The Fail_possibility is on a scale 0f 0ut of 100.
data.plot(x='Fail_possibility',y='failure_probability',style='*')
plt.xlabel('Fail_possibility')
plt.ylabel('failure_probability')
plt.show()
